# %% [markdown]
# # Title
# What we want to do

# %% [markdown]
# ## Imports

# %%
run -i ../scripts/standardimports

# %% [markdown]
# ## User Settings

# %%
image_path = "../images/empty-boards/empty-1.jpg"

bool_plot = True
bool_save = False

# %% [markdown]
# ## Setup

# %%
img = cv2.imread(image_path)
plt.imshow(img)

# %% [markdown]
# ## The new part

# %% [markdown]
# ## The End.

# %%
t_notebook = time.time()-tStart_notebook
print("Runtime of this notebook: {} s = {} min".format(t_notebook, t_notebook / 60))
# Out:
# Runtime of this notebook: 0.23807477951049805 s = 0.0039679129918416345 min
