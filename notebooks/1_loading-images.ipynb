# %% [markdown]
# # loading images and working on them

# %% [markdown]
# ## Imports

# %%
run -i ../scripts/standardimports

# %% [markdown]
# ## User settings

# %%
image_path = "../images/empty-boards/empty-1.jpg"

# %% [markdown]
# ## loading image

# %% [markdown]
# ### with imageio

# %%
img = iio.imread(image_path)
# Out:
# /var/folders/_k/q9sdsmfx2j35cmp3z9tn84km0000gp/T/ipykernel_1372/1472319697.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread(image_path)

# %%
len_y, len_x, __ = img.shape

# %% [markdown]
# - pixel `[0, 0]` is at the top left
# - pixel `[len_y-1, 0]` is at the bottom left
# - pixel `[len_y-1, len_x-1]` is at the bottom right
# - pixel `[0, len_x-1]` at at the top right
# - pixel color is in RGB format

# %%
pos_y, pos_x = 0, 0 # pixel position
rgb = [0, 0, 0] # color in RGB, as an int between 0 and 255

# set color at pixel
img[pos_y, pos_x, :] = rgb

# %% [markdown]
# One issue is that when saved in jpg-format, saving and loading is not the identity:

# %%
# write it
iio.imwrite("test.jpg", img)

# load it again
img2 = iio.imread("test.jpg")

print("Images are the same:", np.isclose(img, img2).all())
# Out:
# Images are the same: False
# /var/folders/_k/q9sdsmfx2j35cmp3z9tn84km0000gp/T/ipykernel_1372/1352264092.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img2 = iio.imread("test.jpg")

# %% [markdown]
# However, it works when using png format

# %%
# write it
iio.imwrite("test.png", img)

# load it again
img2 = iio.imread("test.png")

print("Images are the same:", np.isclose(img, img2).all())
# Out:
# /var/folders/_k/q9sdsmfx2j35cmp3z9tn84km0000gp/T/ipykernel_1372/158776611.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img2 = iio.imread("test.png")
# Images are the same: True

# %% [markdown]
# ### with matplotlib

# %% [markdown]
# According to the matplotlib documentation for `matplotlib.image.imread` at https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imread.html, the image loading function only exists for historical reasons. It is suggested to use the pillow library instead. The function is also a bit complicated to use because png files are read with RGB vales between 0 and 1, and if a png image is saved with `matplotlib.imsave` then it's suddenly also getting an alpha value. I'm therefore ignoring `matplotlib` for saving and loading. A nice thing is the plotting function though to see where the pixels are located:

# %%
plt.imshow(img)

# %% [markdown]
# ### with Pillow

# %% [markdown]
# Pillow (PIL Fork, https://pillow.readthedocs.io/en/stable/) seems a lot to get into, so I'm ignoring it for now. For reading and saving, `imageio` is enough.

# %% [markdown]
# ### with OpenCV

# %%
img = cv2.imread(image_path)

# %%
plt.imshow(img)

# %% [markdown]
# ## The End.

# %%
print("Runtime of this notebook: {} s".format(time.time()-tStart_notebook))
# Out:
# /var/folders/_k/q9sdsmfx2j35cmp3z9tn84km0000gp/T/ipykernel_1372/1472319697.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread(image_path)
